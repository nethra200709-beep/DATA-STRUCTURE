# %%
class Node:
    def __init__(self,x):
        self.data=x
        self.next=None

class Mystack:
    def __init__(self):
        self.top=None
        self.count=0
    

    def push(self,x):
        temp=Node(x)
        temp.next=self.top
        self.top=temp
        self.count +=1

    def pop(self):
        if self.top is None:
            print("stack underflow")
            return -1

        temp=self.top
        self.top=self.top.next
        self.count -=1
        return temp.data

    def peek(self):
        if self.top is None:
            print("stack is empty")
            return -1
        return self.top.data

    def isEmpty(self):
        return self.top is None

    def size(self):
        return self.count

st= Mystack()
n=int(input("enter the number of elements to push:"))
for i in range(n):
    x=int(input("enter element {i+1}:"))
    st.push(x)
          
print("popped element:",st.pop())
print("top element:",st.peek())

if st.isEmpty():
    print("stack is empty")
else:
    print("stack is not empty:")
print("current size:",st.size())
# Out:
# enter the number of elements to push: 6
# enter element {i+1}: 1
# enter element {i+1}: 2
# enter element {i+1}: 3
# enter element {i+1}: 4
# enter element {i+1}: 5
# enter element {i+1}: 6
# popped element: 6
# top element: 5
# stack is not empty:
# current size: 5
