# %%
arr=[10,20,30,40,50]
for element in arr:
    print(element)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
arr=[10,20,40,50]
arr.insert(2,30)
print(arr)
# Out:
# [10, 20, 30, 40, 50]

# %%
arr=[10,20,30,40,50]
arr.remove(30)
print(arr)
# Out:
# [10, 20, 40, 50]

# %%
arr=[10,20,30,40,50]
key=30
if key in arr:
    print("elememt found")
else:
    print("element not found")
# Out:
# elememt found

# %%
arr=[10,20,30,40,50]
key=60
if key in arr:
    print("elememt found")
else:
    print("element not found")
# Out:
# element not found

# %%
arr=[10,20,30,40,50]
arr[2]=35
print(arr)
# Out:
# [10, 20, 35, 40, 50]

# %%
arr=[40,10,50,20,30]
arr.sort()
print(arr)
# Out:
# [10, 20, 30, 40, 50]

# %%
arr=[40,10,50,20,30]
print(arr[4])
# Out:
# 30
